# %% [markdown]
# ** *italicized text*Reference model**
#
# \begin{cases} y'' + a y' + b y= f(x) \\ y(0)= y_0 \\ y'(0)= y_0'\end{cases}
#
# *Example*
#
# **Differential equation:**
#
# \begin{cases} y'' + 9y = 0\,, \\ y\left({\pi\over 4}\right)= 0\,, \\ y'\left({\pi\over 4}\right)= 3\sqrt{2}\,.\end{cases}
#
#
# **General solution:**
#
# y =
# ​
#  C1 cos(3x)+C2 sin(3x)
#
#
# **​Solution (with initial condition):**
#
# y= − cos(3x) − sin(3x)
#
#
#
#
# ​

# %% [markdown]
# **Initialization and symbolic variables**

# %%
#Importing Symbolic library and its initialization

import sympy as sy
sy.init_printing()
from sympy.plotting import plot

#Some common variables declaration

x = sy.symbols('x')

y = sy.Function('y')
y1 = sy.Derivative(y(x), x)
y2 = sy.Derivative(y(x), x, x)

# %% [markdown]
# **General solution**

# %%
#General solution without the initial value

#Definiting the expression

eqdiff = y2 + 9*y(x)

#Solution

sol = sy.dsolve(eqdiff, y(x))

#Print the solution
sy.pprint(sol)
# Out:
# y(x) = C₁⋅sin(3⋅x) + C₂⋅cos(3⋅x)

# %% [markdown]
# **Solution with the initial condition**

# %%
#Solution with the given initial condition

x0 = sy.pi/4
sy.dsolve(eqdiff, y(x), ics={y(x0): 0, y(x).diff(x).subs(x, x0): 3*sy.sqrt(2)})
# Out:
# y(x) = -sin(3⋅x) - cos(3⋅x)

# %% [markdown]
# **Assignment 4**

# %% [markdown]
# ***Question 1***: Solve the second order differential equation $y''+ 16y = 0$
#
# ***Question 2***: Solve the 2nd order differential equation $y'' - 6y' + 5y = 0$
#
# ***Question 3***: Solve the initial-value problem
#
# $y'' - y' + 6y = 0$
#
# $y(0)=1$ and $y'(0)=0$

# %%
#Question 1: 
import sympy as sy
sy.init_printing()
from sympy.plotting import plot

x = sy.symbols('x')
y = sy.Function('y')
y1 = sy.Derivative(y(x), x)
y2 = sy.Derivative(y(x), x, x)

fun = y2 + 16*y(x)
ans = sy.dsolve(fun, y(x))
sy.pprint(ans)
# Out:
# y(x) = C₁⋅sin(4⋅x) + C₂⋅cos(4⋅x)

# %%
#Question 2: 
x = sy.symbols('x')
y = sy.Function('y')
y1 = sy.Derivative(y(x), x)
y2 = sy.Derivative(y(x), x, x)

fun = y2- 6*y1 + 5*y(x)
ans = sy.dsolve(fun, y(x))
sy.pprint(ans)
# Out:
#        ⎛         4⋅x⎞  x
# y(x) = ⎝C₁ + C₂⋅ℯ   ⎠⋅ℯ

# %%
#Question 3: 
x = sy.symbols('x')
y = sy.Function('y')
y1 = sy.Derivative(y(x), x)
y2 = sy.Derivative(y(x), x, x)


fun = y2 - y1 + 6*y(x)
sy.dsolve(fun, y(x),  ics={y(0): 1, y(x).diff(x).subs(x, 0): 0})
# Out:
#        ⎛         ⎛√23⋅x⎞             ⎞  x
#        ⎜  √23⋅sin⎜─────⎟             ⎟  ─
#        ⎜         ⎝  2  ⎠      ⎛√23⋅x⎞⎟  2
# y(x) = ⎜- ────────────── + cos⎜─────⎟⎟⋅ℯ
#        ⎝        23            ⎝  2  ⎠⎠
